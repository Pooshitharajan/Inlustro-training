# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooshitharajan/Inlustro-training/blob/main/LangChain%20with%20Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install LangChain

# %%
pip install langchain community

# %%
pip install langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.16 which is incompatible.
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-1.5-pro",google_api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
response = llm.invoke("Explain langChain in simple term.")
print(response)
# Out:
# content="Imagine you have a really smart robot butler that can access and process information from all sorts of places – websites, databases, PDFs, even Word documents.  LangChain is like the instruction manual that tells this robot butler *how* to use that information to do useful things.\n\nInstead of just giving you raw data, LangChain helps the robot butler:\n\n* **Understand your requests:**  You can ask it complex questions or give it complicated tasks in plain English.\n* **Figure out the best sources of information:**  It knows where to look for the answers, whether it's on Wikipedia or in a company database.\n* **Combine information from different sources:** It can piece together information from multiple places to give you a complete answer.\n* **Remember previous interactions:**  So it can carry on a conversation or build on previous tasks.\n* **Take action:** It can do more than just answer questions.  It can write emails, summarize documents, translate languages, and eve
# ...

# %%
prompt=PromptTemplate(input_variables=["question"],template="You are a helpful AI assistant.Answer the following question:{question}")

# %%
def search_tool(query):
    return f"Searching online for: {query}..."
search = Tool(name="Search",func=search_tool,description="A simple search tool")

# %%
agent=initialize_agent(
    tools=[search],
    llm=llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True
)

# %%
memory=ConversationBufferMemory(memory_key="chat_history")
chain=LLMChain(llm=llm,prompt=prompt,memory=memory)

# %%
import time
print(chain.run("What is Langchain?"))
time.sleep(3)
response2=chain.run("How does it compare to OpenAI?")
print(response2)
# Out:
# <ipython-input-39-b9d1879871e2>:2: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   print(chain.run("What is Langchain?"))
# LangChain is a powerful, open-source framework specifically designed for developing applications powered by language models.  It simplifies the process of creating these applications by providing a standard interface and abstractions for common tasks like:
#
# * **Chain of Thought Reasoning:**  Breaking down complex tasks into smaller, more manageable steps that a language model can handle sequentially. This allows for more robust and logical reasoning.
#
# * **Data Augmented Generation:**  Enriching the context provided to the language model with relevant information retrieved from external sources like Wikipedia, databases, or your own documents. This leads to more accurate and informed outputs.
#
# ...
