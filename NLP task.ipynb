# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,LancasterStemmer,SnowballStemmer
from nltk.corpus import wordnet
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text="She was playing khokho"
tokens=word_tokenize(text)
print("Original Tokens",tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-273182b3c806> in <cell line: 0>()
#       1 text="She was playing kabaddi"
# ----> 2 tokens=word_tokenize(text)
#       3 print("Original Tokens",tokens)
#
# NameError: name 'word_tokenize' is not defined

# %%
porter = PorterStemmer()
stemmed_words = [porter.stem(word) for word in tokens]
print("Porter Stemmer:",stemmed_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8e8fb5655623> in <cell line: 0>()
# ----> 1 porter = PorterStemmer()
#       2 stemmed_words = [porter.stem(word) for word in tokens]
#       3 print("Porter Stemmer:",stemmed_words)
#
# NameError: name 'PorterStemmer' is not defined

# %%
nltk.download('averaged_perceptron_tagget_eng')
pos_tags = pos_tag(custom_filtered_tokens)
 print(POS Tags:",pos_tags)
# Out:
#   File "<ipython-input-40-601c70241182>", line 3
#     print(POS Tags:",pos_tags)
#     ^
# IndentationError: unexpected indent

# %%
tokens=[word.lower()for word in takens]
Print("Lowercased Tokens:",tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-30d106f1a8bf> in <cell line: 0>()
# ----> 1 tokens=[word.lower()for word in takens]
#       2 Print("Lowercased Tokens:",tokens)
#
# NameError: name 'takens' is not defined

# %%
default_stopwords=set(stopwords.words('english'))
default_filtered_tokens=[word for word in tokens if word not in default_stopwords]
Print("tokens after removing default stopwords:",default_filtered_tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-2f678b267d88> in <cell line: 0>()
#       1 default_stopwords=set(stopwords.words('english'))
# ----> 2 default_filtered_tokens=[word for word in tokens if word not in default_stopwords]
#       3 Print("tokens after removing default stopwords:",default_filtered_tokens)
#
# NameError: name 'tokens' is not defined
