# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooshitharajan/Inlustro-training/blob/main/RP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.generativeai import GenerativeModel,configure
configure(api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model=GenerativeModel("gemini-1.5-pro")
r=model.generate_content("Who are You?")
print(r.text)
r=model.generate_content("best mobile in this year")
print(r.text)
# Out:
# I am a large language model, trained by Google.
# There's no single "best" mobile phone in 2024, as the ideal device depends on individual needs and preferences.  However, some of the top contenders across different categories include:
#
# **Flagship/Premium:**
#
# * **Samsung Galaxy S24 Ultra:**  Typically excels in camera technology, display quality, and performance.  Expect a high price tag.
# * **iPhone 15 Pro/Pro Max:** Known for its seamless iOS ecosystem, powerful processor, and strong video recording capabilities. Also expensive.
# * **Google Pixel 8 Pro:**  Prioritizes computational photography and clean Android software.  Often a slightly more affordable flagship option.
# * **OnePlus 12:** Offers competitive specs and fast charging at a generally lower price than other flagships.
#
# **Mid-Range:**
#
# * **Google Pixel 7a:** Excellent camera for the price, clean Android experience, and good performance.
# ...
